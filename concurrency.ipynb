# %%
# Gloabl Interpreter Lock (GIL) is a mutex that allows only one thread to execute Pythone bytecode at a time

'''
CPU-bound tasks -> use multiprocessing
I/O-bound tasks -> threading or async/await
'''
