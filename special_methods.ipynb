# %%
# interpreter invokes special methods to perform basic object operations
# special methods = dunder methods

# %%
'''
my_collection[key] syntax
is supprted by __getitem__ special method
the interpreter calls my_collection.__getitem__(key)
in order to evaluate the operation
'''

# %%
import collections
Card = collections.namedtuple('Card', ['rank', 'suit'])

class FrenchDeck:
    ranks = [str(n) for n in range(2,11)] + list('JQKA')
    suits = 'spades diamonds clubs hearts'.split()

    def __init__(self):
        self._cards = [Card(rank, suit) for suit in self.suits
                                        for rank in self.ranks]
